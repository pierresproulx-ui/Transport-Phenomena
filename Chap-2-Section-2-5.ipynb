# %% [markdown]
# |<img  src="images/usherb_transp.gif" > |Pierre Proulx, ing, professeur|
# |:---|:---|
# |Département de génie chimique et de génie biotechnologique |** GCH200-Phénomènes d'échanges I **|

# %% [markdown]
# ### Section 2.5 Écoulement de deux fluides visqueux adjacents sur un plan.
# > Pour cet exemple on ira directement à l'équation diférentielle puisqu'on a déjà fait le même type de bilans à la section 2.2 en détails.

# %% [markdown]
# ><img src='images/Chap-2-Section-2-5.png' width="700" height="700">

# %%
#
# Pierre Proulx
#
# Préparation de l'affichage et des outils de calcul symbolique
#
import sympy as sp
from IPython.display import *
sp.init_printing(use_latex=True)
# %matplotlib inline

# %%
# définition des variables symboliques et des lois de Newton, voir figure ci-haut
x,p_0,p_L,mu1,mu2,L,B=sp.symbols('x,p_0,p_L,mu_I,mu_II,L,B')
tau_xz1=sp.Function('tau_xz^I')
tau_xz2=sp.Function('tau_xz^II')
C11,C12,C21,C22,C1,C2=sp.symbols('C_11,C_12,C_21,C_22,C1,C2')
vz1=sp.Function('v_z^I')(x)
vz2=sp.Function('v_z^II')(x)
#
# Lois de Newton
#
newton1=-mu1*sp.Derivative(vz1,x) 
newton2=-mu2*sp.Derivative(vz2,x)

# %% [markdown]
# #### Le bilan est identique à celui fait dans la section 2, sans la gravité, alors le résultat est simple, pour chacun des deux fluides on a le résultat du bilan montré sur la figure ci-haut:

# %%
# Bilan des forces
eq1=sp.Eq(tau_xz1(x)-(p_0-p_L)*x/L+C11,0)
eq2=sp.Eq(tau_xz2(x)-(p_0-p_L)*x/L+C12,0)
eq1=eq1.subs(tau_xz1(x),newton1)
eq2=eq2.subs(tau_xz2(x),newton2)
display(eq1)
display(eq2)
# Out:
#           d               x⋅(p₀ - p_L)
# C₁₁ - μ_I⋅──(v_z__I(x)) - ──────────── = 0
#           dx                   L
#            d                x⋅(p₀ - p_L)
# C₁₂ - μ_II⋅──(v_z__II(x)) - ──────────── = 0
#            dx                    L

# %%
vz1=sp.dsolve(eq1,vz1)
vz2=sp.dsolve(eq2,vz2)
#
# Chaque dsolve génère une nouvelle constante par intégration, On les renomme ici pour respecter notre 
# convention. Vous pouvez vérifier en faisant display des vz avant ces remplacements. On veut avoir
# la même notation que celle de Transport Phenomena autant que possible.
#
vz1=vz1.subs(C1,C21)
vz2=vz2.subs(C1,C22)
vz1=vz1                  
vz2=vz2
display(vz1)
display(vz2)
# Out:
#                                2         2
#             C₁₁⋅x          p₀⋅x     p_L⋅x
# v_z__I(x) = ───── + C₂₁ - ─────── + ───────
#              μ_I          2⋅L⋅μ_I   2⋅L⋅μ_I
#                                 2           2
#              C₁₂⋅x          p₀⋅x       p_L⋅x
# v_z__II(x) = ───── + C₂₂ - ──────── + ────────
#              μ_II          2⋅L⋅μ_II   2⋅L⋅μ_II

# %%
# On peut solutionner directement les 4 constantes avec les 4 conditions aux limites
#
# Ici étant donné qu'on travaille avec sympy qui fera la solution automatiquement, on ne se préocuppe
# pas de décomposer le problème en plusieurs morceaux, on va directement à 4 équations et 4 inconnues
# en fonction des 4 conditions aux limites
#
vz1=vz1.rhs                 # prendre la partie de droite nous simplifiera les manips après
vz2=vz2.rhs
condition_1=sp.Eq(vz1.subs(x,0),vz2.subs(x,0))                                 # vitesses égales à l'interface
condition_2=sp.Eq(mu1*sp.diff(vz1,x).subs(x,0),mu2*sp.diff(vz2,x).subs(x,0))   # cisaillement égaux
condition_3=sp.Eq(vz1.subs(x,B),0)                                             # non glissement
condition_4=sp.Eq(vz2.subs(x,-B),0)                                            # non glissement
display(condition_1)
display(condition_2)
display(condition_3)
display(condition_4)
# Out:
# C₂₁ = C₂₂
# C₁₁ = C₁₂
#     2        2
#    B ⋅p₀    B ⋅p_L    B⋅C₁₁
# - ─────── + ─────── + ───── + C₂₁ = 0
#   2⋅L⋅μ_I   2⋅L⋅μ_I    μ_I
#     2          2
#    B ⋅p₀      B ⋅p_L    B⋅C₁₂
# - ──────── + ──────── - ───── + C₂₂ = 0
#   2⋅L⋅μ_II   2⋅L⋅μ_II   μ_II

# %%
constantes=sp.solve([condition_1,condition_2,condition_3,condition_4],sp.symbols('C_11,C_12,C_21,C_22')) 
display(constantes)
# Out:
# ⎧                                                                              ↪
# ⎪     -B⋅μ_I⋅p₀ + B⋅μ_I⋅p_L + B⋅μ_II⋅p₀ - B⋅μ_II⋅p_L       -B⋅μ_I⋅p₀ + B⋅μ_I⋅p ↪
# ⎨C₁₁: ──────────────────────────────────────────────, C₁₂: ─────────────────── ↪
# ⎪                   2⋅L⋅μ_I + 2⋅L⋅μ_II                                   2⋅L⋅μ ↪
# ⎩                                                                              ↪
#
# ↪                                    2       2            2       2    ⎫
# ↪ _L + B⋅μ_II⋅p₀ - B⋅μ_II⋅p_L       B ⋅p₀ - B ⋅p_L       B ⋅p₀ - B ⋅p_L⎪
# ↪ ───────────────────────────, C₂₁: ──────────────, C₂₂: ──────────────⎬
# ↪ _I + 2⋅L⋅μ_II                     L⋅μ_I + L⋅μ_II       L⋅μ_I + L⋅μ_II⎪
# ↪                                                                      ⎭

# %%
vz1=vz1.subs(constantes)
vz2=vz2.subs(constantes)
display(vz1)
display(vz2)
display(type(vz2))
# Out:
#  2       2                                                                 2   ↪
# B ⋅p₀ - B ⋅p_L   x⋅(-B⋅μ_I⋅p₀ + B⋅μ_I⋅p_L + B⋅μ_II⋅p₀ - B⋅μ_II⋅p_L)    p₀⋅x    ↪
# ────────────── + ────────────────────────────────────────────────── - ───────  ↪
# L⋅μ_I + L⋅μ_II                μ_I⋅(2⋅L⋅μ_I + 2⋅L⋅μ_II)                2⋅L⋅μ_I  ↪
#
# ↪        2
# ↪   p_L⋅x
# ↪ + ───────
# ↪   2⋅L⋅μ_I
#  2       2                                                                 2   ↪
# B ⋅p₀ - B ⋅p_L   x⋅(-B⋅μ_I⋅p₀ + B⋅μ_I⋅p_L + B⋅μ_II⋅p₀ - B⋅μ_II⋅p_L)    p₀⋅x    ↪
# ────────────── + ────────────────────────────────────────────────── - ──────── ↪
# L⋅μ_I + L⋅μ_II               μ_II⋅(2⋅L⋅μ_I + 2⋅L⋅μ_II)                2⋅L⋅μ_II ↪
#
# ↪          2
# ↪     p_L⋅x
# ↪  + ────────
# ↪    2⋅L⋅μ_II
# sympy.core.add.Add

# %% [markdown]
# ### Maintenant on tracera les profils en variant les viscosités.

# %%
from ipywidgets import *
def f(r21):
    dico={'mu_I':0.001,'B':0.01, 'L':10,'p_0':100,'p_L':0}
    mu2=r21*mu1.subs(dico)
    vz1p=vz1.subs(dico).subs('mu_II',mu2)
    vz2p=vz2.subs(dico).subs('mu_II',mu2)
    b=B.subs(dico)  
    import matplotlib.pyplot as plt
    plt.rcParams['figure.figsize']=7,5
    p=sp.plot((vz1p,(x,0,b)),(vz2p,(x,-b,0)),legend=True,show=False)
    p.title='Deux fludes immiscibles'
    p[0].label='mu_1=0.001'
    p[0].line_color='red'
    string='mu_2='+str(mu2)[0:6]
    p[1].label=string
    p[1].line_color='blue'
    p.show()
    return
interact(f,r21=(0.2,5.2,0.1)); # r21 est le ratio mu2/mu1, mu2 est tracé à gauche
#
# interact() ou variable=interactive() suivi de display(variable)
# les deux sont équivalents.
# Out:
# interactive(children=(FloatSlider(value=2.7, description='r21', max=5.2, min=0.2), Output()), _dom_classes=('w…
