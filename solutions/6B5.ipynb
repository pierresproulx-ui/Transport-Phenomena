# %% [markdown]
# |<img style="float:left;" src="../images/usherb_transp.gif" width=90% height=90%> |<big>Pierre Proulx, ing, professeur</big>|
# |:---|:---|
# |Département de génie chimique et de génie biotechnologique |** GCH200-Phénomènes d'échanges I **|

# %% [markdown]
# ### Exercice 6B5

# %%
#
# Pierre Proulx
#
# Préparation de l'affichage et des outils de calcul symbolique
#
import sympy as sp
from IPython.display import *
import thermo as th
sp.init_printing(use_latex=True)
# Paramètres, variables et fonctions
rho,L,D,mu,Q,dP=sp.symbols('rho,L,D,mu,Q,dP')

# %%
f=1/4*(D/L)*(dP/((1/2)*rho*(Q/(sp.pi*D**2/4))**2)) # equation définissant le facteur f
Re=4*Q*rho/(sp.pi*mu*D)              # Reynolds avec le débit volumique au lieu de la vitesse                     
f_T=0.0791/Re**0.25                  # si 6.2-12 est valide
#
solution1=sp.solve(f-f_T,dP)
dp1=solution1[0]
dp2=solution1[0].subs(D,D/2)
display((dp2/dp1).evalf(4))
# Out:
# 26.91

# %% [markdown]
# ### Pour la partie b), on peut utiliser le graphe 6.2-1 et effectuer la solution en trouvant f '' à la main'', en sachant que le $\Delta P$ est directement proportionnel au facteur de friction f. On peut aussi utiliser des méthodes de solution numériques en utilisant les expression 6.2-15 ou 6.2-13, on verra comment au chapitre 7.
