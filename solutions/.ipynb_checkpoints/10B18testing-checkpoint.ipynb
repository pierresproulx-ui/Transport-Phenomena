# %% [markdown]
# |<img style="float:left;" src="../images/usherb_transp.gif" width=90% height=90%> |<big>Pierre Proulx, ing, professeur</big>|
# |:---|:---|
# |Département de génie chimique et de génie biotechnologique |** GCH200-Phénomènes d'échanges I **|

# %% [markdown]
# ### Probleme 10B18
#
#
# Le réacteur catalytique a 3 sections, seule la section du milieu a une source thermique
# <img src='http:\\pierreproulx.pheno.ca\prob-10-B-18.png'>
# La solution est identique à celle de la section 10.5, la seule différence est de remplacer S par $ S*T_2 $
#
# Les profils de température ne sont pas aussi différents de ceux que l'on a calculé dans la section 10.5 par rapport au texte, rappelons qu'on n'avait pas négligé les termes de conduction, contrairement à Bird. Les expressions obtenues deviennent extrêmement lourdes, mais *SYMPY* fait le travail pour nous et le travail de mise en place des équations est exactement le même.

# %%
#
# Pierre Proulx
#
#
# Préparation de l'affichage et des outils de calcul symbolique
#
import sympy as sp
from IPython.display import *
sp.init_printing(use_latex=True)
# %matplotlib inline
import numpy as np

# %%
# Paramètres, variables et fonctions, on utilise directement les équations définies
# plus haut
#
rho,c_p,v_0,k_eff,S,z,F=sp.symbols('rho,c_p,v_0,k_eff,S,z,F')
#F=rho*v_0*c_p/k_eff
T_1=sp.Function('T_1')(z)
T_2=sp.Function('T_2')(z)
T_3=sp.Function('T_3')(z)
eq1=sp.Eq(sp.diff(T_1,z,z)-F*sp.diff(T_1,z),0)
eq2=sp.Eq(sp.diff(T_2,z,z)-F*sp.diff(T_2,z)+S*T_2,0)
eq3=sp.Eq(sp.diff(T_3,z,z)-F*sp.diff(T_3,z),0)
T_1=sp.dsolve(eq1,T_1).rhs
T_2=sp.dsolve(eq2,T_2).rhs  # rhs pour avoir seulement a droite de l'égalité
T_3=sp.dsolve(eq3,T_3).rhs
#
# Renommer les constantes C1 et C2 dans les équations 2 et 3
#
T_2=T_2.subs(sp.symbols('C1'),sp.symbols('C3'))
T_2=T_2.subs(sp.symbols('C2'),sp.symbols('C4'))
T_3=T_3.subs(sp.symbols('C1'),sp.symbols('C5'))
T_3=T_3.subs(sp.symbols('C2'),sp.symbols('C6'))
display(T_1)
display(T_2)
display(T_3)
# Out:
#          F⋅z
# C₁ + C₂⋅ℯ
#       ⎛       __________⎞         ⎛       __________⎞
#       ⎜      ╱  2       ⎟         ⎜      ╱  2       ⎟
#     z⋅⎝F - ╲╱  F  - 4⋅S ⎠       z⋅⎝F + ╲╱  F  - 4⋅S ⎠
#     ─────────────────────       ─────────────────────
#               2                           2
# C₃⋅ℯ                      + C₄⋅ℯ
#          F⋅z
# C₅ + C₆⋅ℯ

# %%
#
# On peut calculer les flux de Fourier 
#
q_1 =-k_eff*sp.diff(T_1,z)
q_2 =-k_eff*sp.diff(T_2,z)
q_3 =-k_eff*sp.diff(T_3,z)

# %%
# écrivons les équations de base qui seront utilisées, au besoin
group=sp.sqrt(F*F-4*S)
G=sp.symbols('G')
T_2=T_2.subs(group,G)
q_2=q_2.subs(group,G)
display(T_1)
display(T_2)
display(T_3)
display(q_1)
display(q_2)
display(q_3)
# Out:
#          F⋅z
# C₁ + C₂⋅ℯ
#     z⋅(F - G)       z⋅(F + G)
#     ─────────       ─────────
#         2               2
# C₃⋅ℯ          + C₄⋅ℯ
#          F⋅z
# C₅ + C₆⋅ℯ
#              F⋅z
# -C₂⋅F⋅k_eff⋅ℯ
#        ⎛            z⋅(F - G)               z⋅(F + G)⎞
#        ⎜            ─────────               ─────────⎟
#        ⎜   ⎛F   G⎞      2          ⎛F   G⎞      2    ⎟
# -k_eff⋅⎜C₃⋅⎜─ - ─⎟⋅ℯ          + C₄⋅⎜─ + ─⎟⋅ℯ         ⎟
#        ⎝   ⎝2   2⎠                 ⎝2   2⎠           ⎠
#              F⋅z
# -C₆⋅F⋅k_eff⋅ℯ

# %%
# Les conditions aux limites, 6 équations car 6 inconnues.
#
# En z=0, T1 est la valeur d'entrée, T0
T_0,z_1,z_2=sp.symbols('T_0,z_1,z_2')
CL1=sp.Eq(T_1.subs(z,0)-T_0,0)
# En z=z1, la température des deux milieux sont égales     T_1(z1) = T_2(z1)
CL2=sp.Eq(T_1.subs(z,z_1)-T_2.subs(z,z_1),0)
# en z=z1, le flux des deux milieux sont égaux             q_1(z1) = q_2(z1)
CL3=sp.Eq(q_1.subs(z,z_1)-q_2.subs(z,z_1),0)
# en z=z2,  la température des deux milieux sont égales    T_2(z2) = T_3(z2)
CL4=sp.Eq(T_2.subs(z,z_2)-T_3.subs(z,z_2),0)
# en z=z2, le flux des deux milieux sont égaux             q_2(z2) = q_2(z2)
CL5=sp.Eq(q_2.subs(z,z_2)-q_3.subs(z,z_2),0)
# en z=infini, le flux est nul                               q_3(infini) = 0
CL6=sp.Eq(q_3.subs(z,sp.oo),0)
C6=0
dico={'F':1,'c_p':1000,'z_1':1,'z_2':2,'S':3,'T_0':293,'C6':0,'G':1,'k_eff':1}
display(CL1.subs(dico).evalf(),CL2.subs(dico).evalf(),CL3.subs(dico).evalf()
        ,CL4.subs(dico).evalf(),CL5.subs(dico).evalf(),C6)
# Out:
# C₁ + C₂ - 293.0 = 0
# C₁ + 2.71828182845905⋅C₂ - C₃ - 2.71828182845905⋅C₄ = 0
# -2.71828182845905⋅C₂ + 2.71828182845905⋅C₄ = 0
# C₃ + 7.38905609893065⋅C₄ - C₅ = 0
# -7.38905609893065⋅C₄ = 0
# 0

# %%
a=np.array([     [1,          1,         0,          0,  0,],
                [1,   22026.47,  -1.36286,   16161.96,  0],
                [0, -220264.66,   0.42192,  156616.14,  0],
                [0,          0, 1.8573829,  261209028, -1],
                [0,          0, -0.575016, 2531224084,  0]])
b=np.array([293, 0, 0, 0, 0])
x=np.linalg.solve(a,b)
print(x)
constantes=sp.solve([CL1,CL2,CL3,CL4,CL5]
                    ,sp.symbols('C1,C2,C3,C4,C5'))
display(constantes)
# Out:
# [2.92999575e+02 4.25008509e-04 2.21858318e+02 5.03993634e-08
#  4.25240614e+02]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       7 x=np.linalg.solve(a,b)
#       8 print(x)
# ----> 9 constantes=sp.solve([CL1,CL2,CL3,CL4,CL5]
#      10                     ,sp.symbols('C1,C2,C3,C4,C5'))
#      11 display(constantes)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/solvers/solvers.py:1172, in solve(f, *symbols, **flags)
#    1170         solution = _solve(f[0], *symbols, **flags)
#    1171 else:
# -> 1172     linear, solution = _solve_system(f, symbols, **flags)
#    1173 assert type(solution) is list
#    1174 assert not solution or type(solution[0]) is dict, solution
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/solvers/solvers.py:1859, in _solve_system(exprs, symbols, **flags)
#    1857     result = minsolve_linear_system(matrix, *symbols, **flags)
#    1858 else:
# -> 1859     result = solve_linear_system(matrix, *symbols, **flags)
#    1860 result = [result] if result else []
#    1861 if failed:
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/solvers/solvers.py:2352, in solve_linear_system(system, *symbols, **flags)
#    2350 eqs = list(system * Matrix(symbols + (-1,)))
#    2351 eqs, ring = sympy_eqs_to_ring(eqs, symbols)
# -> 2352 sol = solve_lin_sys(eqs, ring, _raw=False)
#    2353 if sol is not None:
#    2354     sol = {sym:val for sym, val in sol.items() if sym != val}
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/solvers.py:279, in solve_lin_sys(eqs, ring, _raw)
#     276     eqs_rhs.append(eq_rhs)
#     277     eqs_coeffs.append(eq_coeffs)
# --> 279 result = _solve_lin_sys(eqs_coeffs, eqs_rhs, ring)
#     281 if result is not None and as_expr:
#     283     def to_sympy(x):
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/solvers.py:357, in _solve_lin_sys(eqs_coeffs, eqs_rhs, ring)
#     355 sol = {}
#     356 for subsystem in subsystems:
# --> 357     subsol = _solve_lin_sys_component(subsystem[0], subsystem[1], ring)
#     358     if subsol is None:
#     359         return None
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/solvers.py:405, in _solve_lin_sys_component(eqs_coeffs, eqs_rhs, ring)
#     402     matrix = matrix.to_field()
#     404 # solve by row-reduction
# --> 405 echelon, pivots = matrix.rref()
#     407 # construct the returnable form of the solutions
#     408 keys = ring.gens
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/matrices/domainmatrix.py:2228, in DomainMatrix.rref(self, method)
#    2139 def rref(self, *, method='auto'):
#    2140     r"""
#    2141     Returns reduced-row echelon form (RREF) and list of pivots.
#    2142
#    (...)
#    2226
#    2227     """
# -> 2228     return _dm_rref(self, method=method)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/matrices/rref.py:63, in _dm_rref(M, method)
#      60 if method == 'GJ':
#      61     # Use Gauss-Jordan with division over the associated field.
#      62     Mf = _to_field(M)
# ---> 63     M_rref, pivots = _dm_rref_GJ(Mf)
#      65 elif method == 'FF':
#      66     # Use fraction-free GJ over the current domain.
#      67     M_rref_f, den, pivots = _dm_rref_den_FF(M)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/matrices/rref.py:189, in _dm_rref_GJ(M)
#     187     return _dm_rref_GJ_sparse(M)
#     188 else:
# --> 189     return _dm_rref_GJ_dense(M)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/matrices/rref.py:212, in _dm_rref_GJ_dense(M)
#     210 partial_pivot = M.domain.is_RR or M.domain.is_CC
#     211 ddm = M.rep.to_ddm().copy()
# --> 212 pivots = ddm_irref(ddm, _partial_pivot=partial_pivot)
#     213 M_rref_ddm = DDM(ddm, M.shape, M.domain)
#     214 pivots = tuple(pivots)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/matrices/dense.py:217, in ddm_irref(a, _partial_pivot)
#     215 aijinv = aij**-1
#     216 for l in range(j, n):
# --> 217     ai[l] *= aijinv # ai[j] = one
#     219 # eliminate above and below to the right
#     220 for k, ak in enumerate(a):
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/domains/expressiondomain.py:112, in ExpressionDomain.Expression.__mul__(f, g)
#     109 elif f.ex.is_Number and g.ex.is_Number:
#     110     return f.__class__(f.ex*g.ex)
# --> 112 return f.simplify(f.ex*g.ex)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/domains/expressiondomain.py:54, in ExpressionDomain.Expression.simplify(f, ex)
#      53 def simplify(f, ex):
# ---> 54     return f.__class__(ex.cancel().expand(**eflags))
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/expr.py:3782, in Expr.cancel(self, *gens, **args)
#    3780 """See the cancel function in sympy.polys"""
#    3781 from sympy.polys.polytools import cancel
# -> 3782 return cancel(self, *gens, **args)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/polys/polytools.py:7155, in cancel(f, _signsimp, *gens, **args)
#    7153 f = sympify(f)
#    7154 if _signsimp:
# -> 7155     f = signsimp(f)
#    7156 opt = {}
#    7157 if 'polys' in args:
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/simplify/simplify.py:405, in signsimp(expr, evaluate)
#     403     return expr
#     404 # get rid of an pre-existing unevaluation regarding sign
# --> 405 e = expr.replace(lambda x: x.is_Mul and -(-x) != x, lambda x: -(-x))
#     406 e = sub_post(sub_pre(e))
#     407 if not isinstance(e, (Expr, Relational)) or e.is_Atom:
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/basic.py:1749, in Basic.replace(self, query, value, map, simultaneous, exact)
#    1746             expr = v
#    1747     return expr
# -> 1749 rv = walk(self, rec_replace)
#    1750 return (rv, mapping) if map else rv
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/basic.py:1724, in Basic.replace.<locals>.walk(rv, F)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/basic.py:1724, in Basic.replace.<locals>.walk(rv, F)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
#     [... skipping similar frames: Basic.replace.<locals>.walk at line 1724 (2 times)]
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/basic.py:1724, in Basic.replace.<locals>.walk(rv, F)
#    1722 if args is not None:
#    1723     if args:
# -> 1724         newargs = tuple([walk(a, F) for a in args])
#    1725         if args != newargs:
#    1726             rv = rv.func(*newargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/basic.py:1734, in Basic.replace.<locals>.walk(rv, F)
#    1732                     if rv == e and e != newargs[i]:
#    1733                         return rv
# -> 1734     rv = F(rv)
#    1735 return rv
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/basic.py:1740, in Basic.replace.<locals>.rec_replace(expr)
#    1739 def rec_replace(expr):
# -> 1740     result = _query(expr)
#    1741     if result or result == {}:
#    1742         v = _value(expr, result)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/simplify/simplify.py:405, in signsimp.<locals>.<lambda>(x)
#     403     return expr
#     404 # get rid of an pre-existing unevaluation regarding sign
# --> 405 e = expr.replace(lambda x: x.is_Mul and -(-x) != x, lambda x: -(-x))
#     406 e = sub_post(sub_pre(e))
#     407 if not isinstance(e, (Expr, Relational)) or e.is_Atom:
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/mul.py:193, in Mul.__neg__(self)
#     191     else:
#     192         args = (c,) + args
# --> 193 return self._from_args(args, self.is_commutative)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/operations.py:119, in AssocOp._from_args(cls, args, is_commutative)
#     116 elif len(args) == 1:
#     117     return args[0]
# --> 119 obj = super().__new__(cls, *args)
#     120 if is_commutative is None:
#     121     is_commutative = fuzzy_and(a.is_commutative for a in args)
#
# File ~/anaconda3/lib/python3.12/site-packages/sympy/core/basic.py:229, in Basic.__new__(cls, *args)
#     225 is_commutative: bool | None
#     227 kind: Kind = UndefinedKind
# --> 229 def __new__(cls, *args):
#     230     obj = object.__new__(cls)
#     231     obj._assumptions = cls.default_assumptions
#
# KeyboardInterrupt:

# %%
T_1=T_1.subs(constantes)
T_2=T_2.subs(constantes)
T_3=T_3.subs(constantes)
q_1=q_1.subs(constantes)
q_2=q_2.subs(constantes)
q_3=q_3.subs(constantes)
display('T_1',T_1)
display('T_2',T_2)
display('T_3',T_3)
display('q_1',q_1)
display('q_2',q_2)
display('q_3',q_3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 T_1=T_1.subs(constantes)
#       2 T_2=T_2.subs(constantes)
#       3 T_3=T_3.subs(constantes)
#
# NameError: name 'T_1' is not defined

# %%
#
# On utilise des valeurs supposées pour obtenir des profils réalistes
# La première série de graphes est avec une conductivité thermique plus faible
#
dico1={'rho':1,'c_p':1000,'z_1':1,'z_2':2,'k_eff':1,'v_0':.005,'S':3,'T_0':293}
dico2={'rho':1,'c_p':1000,'z_1':1,'z_2':2,'k_eff':2,'v_0':.005,'S':3,'T_0':293}
T_1plot=T_1.subs(dico1)
T_2plot=T_2.subs(dico1)
T_3plot=T_3.subs(dico1)
T_12plot=T_1.subs(dico2)
T_22plot=T_2.subs(dico2)
T_32plot=T_3.subs(dico2)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=10,8
sp.plot((T_1plot,(z,0,1)),(T_2plot,(z,1,2)),(T_3plot,(z,2,3)),
       (T_12plot,(z,0,1)),(T_22plot,(z,1,2)),(T_32plot,(z,2,3)));
