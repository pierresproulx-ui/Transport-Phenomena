# %% [markdown]
# |<img style="float:left;" src="images/usherb_transp.gif" width=90% height=90%> |<big>Pierre Proulx, ing, professeur</big>|
# |:---|:---|
# |Département de génie chimique et de génie biotechnologique |** GCH200-Phénomènes d'échanges I **|

# %% [markdown]
# ### Problème 18B14, Difffusion et réaction dans un catalyseur poreux en forme de disque
#
# <img src='images/Chap-18-Prob18B14.png'>
#
# Voir les hypothèses dans le livre de Transport Phenomena.

# %%
#
# Pierre Proulx
#
# Préparation de l'affichage et des outils de calcul symbolique
#
import sympy as sp
from IPython.display import *
sp.init_printing(use_latex=True)
# %matplotlib inline

# %%
# Paramètres, variables et fonctions
z,delta_z,R,k_1,a,D_A,C_AS,b=sp.symbols('z,delta_z,R,k_1,a,D_A,C_AS,b')                                                            
N_A=sp.Function('N_A')
C_A=sp.Function('C_A')(z)

# %%
#
# Bilan sur une section d'épaisseur dz
#
S=sp.pi*R**2
eq=sp.Eq((S*N_A(z)-S*N_A(z+delta_z))/delta_z-k_1*a*C_A*S,0)
display(eq)
# Out:
#                         2             2
#      2               π⋅R ⋅N_A(z) - π⋅R ⋅N_A(δ_z + z)
# - π⋅R ⋅a⋅k₁⋅C_A(z) + ─────────────────────────────── = 0
#                                    δ_z

# %%
eq=sp.limit(eq.lhs,delta_z,0).doit()
display(eq)
# Out:
#      2                  2 d
# - π⋅R ⋅a⋅k₁⋅C_A(z) - π⋅R ⋅──(N_A(z))
#                           dz

# %%
fick=-D_A*sp.diff(C_A,z)
eq=eq.subs(N_A(z),fick)
display(eq.simplify())
C_A=sp.dsolve(eq)
display(C_A)
# Out:
#      ⎛     2                       ⎞
#    2 ⎜    d                        ⎟
# π⋅R ⋅⎜D_A⋅───(C_A(z)) - a⋅k₁⋅C_A(z)⎟
#      ⎜      2                      ⎟
#      ⎝    dz                       ⎠
#                     ______             ______
#                    ╱ a⋅k₁             ╱ a⋅k₁
#              -z⋅  ╱  ────        z⋅  ╱  ────
#                 ╲╱   D_A           ╲╱   D_A
# C_A(z) = C₁⋅ℯ              + C₂⋅ℯ

# %%
grad=sp.diff(C_A.rhs,z)
cl1=sp.Eq(grad.subs(z,0),0)
display(cl1)
cl2=sp.Eq(C_A.rhs.subs(z,b),C_AS)
display(cl2)
constantes=sp.solve((cl1,cl2),sp.symbols('C1,C2'))
display(constantes)
C_A=C_A.subs(constantes)
display(C_A)                                       # La solution est complète ici, on essaie
C_A=sp.powsimp(C_A)                                # de la mettre sous une forme plus compacte
display(C_A)                                       # mais ce n'est qu'esthétique
C_A=sp.simplify(C_A)
display(C_A)
# Out:
#          ______          ______
#         ╱ a⋅k₁          ╱ a⋅k₁
# - C₁⋅  ╱  ────  + C₂⋅  ╱  ────  = 0
#      ╲╱   D_A        ╲╱   D_A
#            ______             ______
#           ╱ a⋅k₁             ╱ a⋅k₁
#     -b⋅  ╱  ────        b⋅  ╱  ────
#        ╲╱   D_A           ╲╱   D_A
# C₁⋅ℯ              + C₂⋅ℯ             = C_AS
# ⎧                ______                   ______ ⎫
# ⎪               ╱ a⋅k₁                   ╱ a⋅k₁  ⎪
# ⎪          b⋅  ╱  ────              b⋅  ╱  ────  ⎪
# ⎪            ╲╱   D_A                 ╲╱   D_A   ⎪
# ⎪    C_AS⋅ℯ                   C_AS⋅ℯ             ⎪
# ⎨C₁: ───────────────────, C₂: ───────────────────⎬
# ⎪             ______                   ______    ⎪
# ⎪            ╱ a⋅k₁                   ╱ a⋅k₁     ⎪
# ⎪     2⋅b⋅  ╱  ────            2⋅b⋅  ╱  ────     ⎪
# ⎪         ╲╱   D_A                 ╲╱   D_A      ⎪
# ⎩    ℯ               + 1      ℯ               + 1⎭
#                      ______        ______               ______         ______
#                     ╱ a⋅k₁        ╱ a⋅k₁               ╱ a⋅k₁         ╱ a⋅k₁
#                b⋅  ╱  ────   z⋅  ╱  ────          b⋅  ╱  ────   -z⋅  ╱  ────
#                  ╲╱   D_A      ╲╱   D_A             ╲╱   D_A       ╲╱   D_A
#          C_AS⋅ℯ            ⋅ℯ               C_AS⋅ℯ            ⋅ℯ
# C_A(z) = ──────────────────────────────── + ─────────────────────────────────
#                         ______                              ______
#                        ╱ a⋅k₁                              ╱ a⋅k₁
#                 2⋅b⋅  ╱  ────                       2⋅b⋅  ╱  ────
#                     ╲╱   D_A                            ╲╱   D_A
#                ℯ               + 1                 ℯ               + 1
#                      ______        ______               ______         ______
#                     ╱ a⋅k₁        ╱ a⋅k₁               ╱ a⋅k₁         ╱ a⋅k₁
#                b⋅  ╱  ────   z⋅  ╱  ────          b⋅  ╱  ────   -z⋅  ╱  ────
#                  ╲╱   D_A      ╲╱   D_A             ╲╱   D_A       ╲╱   D_A
#          C_AS⋅ℯ            ⋅ℯ               C_AS⋅ℯ            ⋅ℯ
# C_A(z) = ──────────────────────────────── + ─────────────────────────────────
#                         ______                              ______
#                        ╱ a⋅k₁                              ╱ a⋅k₁
#                 2⋅b⋅  ╱  ────                       2⋅b⋅  ╱  ────
#                     ╲╱   D_A                            ╲╱   D_A
#                ℯ               + 1                 ℯ               + 1
#               ⎛       ______        ______          ⎞         ______
#               ⎜      ╱ a⋅k₁        ╱ a⋅k₁           ⎟        ╱ a⋅k₁
#               ⎜ b⋅  ╱  ────       ╱  ──── ⋅(b + 2⋅z)⎟  -z⋅  ╱  ────
#               ⎜   ╲╱   D_A      ╲╱   D_A            ⎟     ╲╱   D_A
#          C_AS⋅⎝ℯ             + ℯ                    ⎠⋅ℯ
# C_A(z) = ───────────────────────────────────────────────────────────
#                                       ______
#                                      ╱ a⋅k₁
#                               2⋅b⋅  ╱  ────
#                                   ╲╱   D_A
#                              ℯ               + 1

# %%
#
# flux molaire * surface = taux de consommation dans le catalyseur
#
surface=sp.pi*R**2*2                  # *2 faces disque mince on néglige les côtés
taux=D_A*sp.diff(C_A.rhs,z).subs(z,b)*surface
display(taux.simplify())                                    
lam=sp.sqrt(k_1*a/D_A)
tauxBird=surface*C_AS*D_A*lam*sp.tanh(lam*b)   # equation 18B.14-2
display(tauxBird)
# Out:
#                     ______     ⎛      ______⎞
#               2    ╱ a⋅k₁      ⎜     ╱ a⋅k₁ ⎟
# 2⋅π⋅C_AS⋅D_A⋅R ⋅  ╱  ──── ⋅tanh⎜b⋅  ╱  ──── ⎟
#                 ╲╱   D_A       ⎝  ╲╱   D_A  ⎠
#                     ______     ⎛      ______⎞
#               2    ╱ a⋅k₁      ⎜     ╱ a⋅k₁ ⎟
# 2⋅π⋅C_AS⋅D_A⋅R ⋅  ╱  ──── ⋅tanh⎜b⋅  ╱  ──── ⎟
#                 ╲╱   D_A       ⎝  ╲╱   D_A  ⎠
