# %% [markdown]
# |<img style="float:left;" src="../images/usherb_transp.gif" width=90% height=90%> |<big>Pierre Proulx, ing, professeur</big>|
# |:---|:---|
# |Département de génie chimique et de génie biotechnologique |** GCH200-Phénomènes d'échanges I **|

# %% [markdown]
# ### Problème 17A2

# %%
# a)
a=[2.745e-4,3.64e-4]
b=[1.823,2.334]
T1=293
f1=T1**b[0]  # non-polaire, dans 17.2-1 tout est constant sauf T, donc le ratio 
T2=1500      # des diffusivités est juste le ratio des T à la puissance b
f2=T2**b[0] 
DAB1=0.151
DAB1*f2/f1
# Out:
# 2.964091736705216

# %%
# c)
import math as math
import thermo as th
def omegaDAB(T,epK):
    T=T/epK
    A=1.06036/T**0.1561
    A+=0.193/math.exp(0.47635*T)
    A+=1.03587/math.exp(1.52996*T)
    A+=1.76474/math.exp(3.89411*T)
    return A
#
epA=190
epB=97
#
epAB=(epA*epB)**0.5
T1=293
T2=1500
ratio=(T2/T1)**1.5*omegaDAB(T1,epAB)/omegaDAB(T2,epAB) # ici T et omega changent, pas sigma.
DAB1*ratio
# Out:
# 2.5116495313841374

# %% [markdown]
# ### La mesure expérimentale est de 2.45, donc la méthode de l'équation 17.3-12 incluant la variation de epsilon et de omega est beaucoup plus précise.
